# %% [markdown]
# ## LLM CALL

# %%
import os
from dotenv import load_dotenv
load_dotenv()

if os.environ['OPENROUTER_API_KEY'] :
    print("OPENAI_API_KEY is set.")
# Out:
# OPENAI_API_KEY is set.

# %%
from openai import OpenAI
from pydantic import SecretStr

client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.environ["OPENROUTER_API_KEY"],
)

response = client.chat.completions.create(
  model="gpt-4o-mini",
  messages=[
          {
            "role": "user",
            "content": "How many r's are in the word 'strawberry'?"
          }
        ]
)

print(response.choices[0].message.content)
# Out:
# The word 'strawberry' contains 2 'r's.

# %% [markdown]
# ## Langchain

# %%
from langchain_openai import ChatOpenAI
from pydantic import SecretStr

llm = ChatOpenAI(
    model="gpt-4o-mini",
    base_url="https://openrouter.ai/api/v1",
    api_key=SecretStr(os.environ["OPENROUTER_API_KEY"]),
    temperature=0,
)

llm.invoke("How many r's are in the word 'strawberry'?").content
# Out:
# "The word 'strawberry' contains 2 'r's."

# %%
from langchain.chat_models import init_chat_model

llm_openai = init_chat_model(
    model="gpt-4o-mini",
    base_url="https://openrouter.ai/api/v1",
    api_key=SecretStr(os.environ["OPENROUTER_API_KEY"])
)

llm_openai.invoke("How many r's are in the word 'strawberry'?").content
# Out:
# "The word 'strawberry' contains 2 'r's."
