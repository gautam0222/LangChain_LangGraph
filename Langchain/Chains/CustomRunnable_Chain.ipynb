# %%
from langchain_openai import ChatOpenAI
import os
from pydantic import SecretStr

llm = ChatOpenAI(
    model="gpt-4o-mini",
    base_url="https://openrouter.ai/api/v1",
    api_key=SecretStr(os.environ["OPENROUTER_API_KEY"])
)

# %% [markdown]
# ## Chain with Custom Runnable

# %%
#Task 1
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("user", "{text}"),
])

# %%
#Task 2
llm_openai = ChatOpenAI(
    model="gpt-4o-mini",
    base_url="https://openrouter.ai/api/v1",
    api_key=SecretStr(os.environ["OPENROUTER_API_KEY"]),
    temperature=0.7
)

# %%
#Task 3
from langchain_core.output_parsers import StrOutputParser

str_parser = StrOutputParser()

# %%
#Task 4
from langchain_core.runnables import RunnableLambda

def dictionary_maker(text: str) -> dict:
    return {"text": text}

dict_maker_runnable = RunnableLambda(dictionary_maker)

# %%
#Task 5
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_messages(
    messages=[
        ("system", "You are social media post generator."),
        ("user", "Create a social media post about: {text}"),
    ]
)

# %%
#Task 6
llm_openai = ChatOpenAI(
    model="gpt-4o-mini",
    base_url="https://openrouter.ai/api/v1",
    api_key=SecretStr(os.environ["OPENROUTER_API_KEY"]),
    temperature=0.7
)

# %%
#Task 7
str_parser = StrOutputParser()

# %% [markdown]
# ## Chain

# %%
chain = prompt_template | llm | str_parser | dict_maker_runnable | prompt_template | llm_openai | str_parser

chain.invoke({"text": "Write a fun fact about programming."})
# Out:
# "🌟💻✨ Fun Fact Friday! ✨ Did you know that the world's first computer programmer was a trailblazing woman? Meet Ada Lovelace! Back in the mid-1800s, she crafted algorithms for Charles Babbage's early mechanical computer long before coding was even a thing! Talk about breaking barriers and paving the way for future generations! 👩\u200d💻🎉 Let's celebrate her legacy and the amazing contributions of women in tech! 💪💖 #WomenInTech #Programming #FunFact #AdaLovelace #Inspiration #TechTrailblazers"
